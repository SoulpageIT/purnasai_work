# %%
import pandas as pd
import numpy as np
import os

# %%
data=pd.read_csv("shadygrove.csv")

# %%
data.head(2)
# Out:
#    Unnamed: 0    direction color        location              problem  delay  \
# 0           8  Shady Grove   Red  Medical Center        brake problem    6.0
# 1          10  Shady Grove   Red   Dupont Circle  a medical emergency    6.0
#
#                                            full text  Month        date  year  \
# 0  8:46 a.m. A Shady Grove-bound Red Line train a...     11  2016-11-16  2016
# 1  8:58 a.m. A Shady Grove-bound Red Line train a...     11  2016-11-16  2016
#
#    hour   period
# 0     8  2016-11
# 1     8  2016-11

# %%
new_data=pd.DataFrame()
new_data['problem']=data['problem']
new_data['date']=data['date']

# %%
new_data.shape
# Out:
# (2951, 2)

# %%
new_data["unique"]=new_data['date']+''+new_data['problem']

# %%
new_data.head(2)
# Out:
#                problem        date                         unique
# 0        brake problem  2016-11-16        2016-11-16brake problem
# 1  a medical emergency  2016-11-16  2016-11-16a medical emergency

# %%
new_data=new_data.drop_duplicates(subset='unique',keep='last')

# %%
new_data=new_data.drop('unique',axis=1)

# %%
##combine all CONDITION_CODE_DATE created above as per patients id.


combine_fea3=new_data.groupby('date')['problem'].apply(' '.join).reset_index()

# %%
combine_fea3
# Out:
#             date                                            problem
# 0     2012-05-04                               an equipment problem
# 1     2012-05-09                                     a door problem
# 2     2012-05-10                                     a door problem
# 3     2012-05-11                       a door problem brake problem
# 4     2012-05-14               brake problem an operational problem
# 5     2012-05-15  a door problem an operational problem did not ...
# 6     2012-05-16        an equipment problem an operational problem
# 7     2012-05-17                                      brake problem
# 8     2012-05-18  a door problem schedule adherence/improved tra...
# 9     2012-05-19                                     a door problem
# 10    2012-05-21                               an equipment problem
# 11    2012-05-22        an operational problem an equipment problem
# 12    2012-05-23        an operational problem an equipment problem
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()                  # converts the character array to numeric array. Assigns levels to unique labels.
combine_fea3["problem1"]=le.fit_transform(combine_fea3["problem"])

# %%
combine_fea3.T
# Out:
#                           0               1               2     \
# date                2012-05-04      2012-05-09      2012-05-10
# problem   an equipment problem  a door problem  a door problem
# problem1                   126               2               2
#
#                                   3                                     4     \
# date                        2012-05-11                            2012-05-14
# problem   a door problem brake problem  brake problem an operational problem
# problem1                            18                                   242
#
#                                                        5     \
# date                                             2012-05-15
# problem   a door problem an operational problem did not ...
# problem1                                                 14
#
#                                                  6              7     \
# date                                       2012-05-16     2012-05-17
# ...

# %%
import pmdarima
from pmdarima import auto_arima

# %%
#using auto arima to get best lowest AIC automatically
stepwise_model = auto_arima(combine_fea3, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-9c192b20fdda> in <module>
#       6                            error_action='ignore',
#       7                            suppress_warnings=True,
# ----> 8                            stepwise=True)
#       9 print(stepwise_model.aic())
#
# /home/purna/snap/jupyter/common/lib/python3.7/site-packages/pmdarima/arima/auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, transparams, solver, maxiter, disp, callback, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, **fit_args)
# ...

# %%
# Fitting on total data
stepwise_model.fit(combine_fea3)

# Prediction on test data
future_forecast = stepwise_model.predict(n_periods= 4)
MH_ts_preds = future_forecast ; print(MH_ts_preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-ffba410de0c8> in <module>
#       1 # Fitting on total data
# ----> 2 stepwise_model.fit(combine_fea3)
#       3
#       4 # Prediction on test data
#       5 future_forecast = stepwise_model.predict(n_periods= 4)
#
# NameError: name 'stepwise_model' is not defined

# %%
data['average_consumption_per_day'] = data.DATE.map(data.groupby(['DATE']).total_consumption.mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-278973972782> in <module>
# ----> 1 data['average_consumption_per_day'] = data.DATE.map(data.groupby(['DATE']).total_consumption.mean())
#
# /home/purna/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'DATE'

# %%
combine_fea3['date']=pd.to_datetime(combine_fea3['date'])

#combine_fea3['date']=pd.to_datetime(combine_fea3['date'],format='%Y').dt.strftime('%Y')
#combine_fea3['date1'] = combine_fea3.date.astype(str).str[:4].astype(int)

# %%
combine_fea3['date_new']=pd.to_datetime(combine_fea3['date'],format='%Y-%m').dt.strftime('%Y-%m')

# %%
combine_fea3.head(2)
# Out:
#         date               problem  problem1 date_new
# 0 2012-05-04  an equipment problem       126  2012-05
# 1 2012-05-09        a door problem         2  2012-05

# %%
#combine_fea3['average'] = combine_fea3.date_new.map(combine_fea3.groupby(['date_new']).problem.mode(0))
combine_fea3['average']=combine_fea3.groupby('problem1').date_new.apply(lambda x: x.mode())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/purna/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/frame.py in reindexer(value)
#    3593                 try:
# -> 3594                     value = value.reindex(self.index)._values
#    3595                 except Exception as e:
#
# /home/purna/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    3737     def reindex(self, index=None, **kwargs):
# -> 3738         return super(Series, self).reindex(index=index, **kwargs)
#    3739
#
# /home/purna/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#
# ...

# %%
combine_fea3['average'] = combine_fea3.date_new.map(combine_fea3.groupby(['date_new']).problem1.mode()[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-79a33ad971ea> in <module>
# ----> 1 combine_fea3['average'] = combine_fea3.date_new.map(combine_fea3.groupby(['date_new']).problem1.mode()[0])
#
# /home/purna/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# /home/purna/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
# ...
